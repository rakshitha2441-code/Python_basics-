# %% [markdown]
# <a href="https://colab.research.google.com/github/rakshitha2441-code/Python_basics-/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("HELLO🌎")
# Out:
# HELLO🌎

# %%
print("Rakshitha")
# Out:
# Rakshitha

# %%
name='Rakshi'
year='2006'
